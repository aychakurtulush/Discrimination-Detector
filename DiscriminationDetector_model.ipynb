# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
tweets = pd.read_csv("Data/tweet_no_duplicates.csv")
tweets = tweets.drop(columns=['Unnamed: 0'], axis=1)
tweets
# Out:
#                              date                   id  \
# 0       2023-02-28 15:15:17+00:00  1630587451436683264
# 1       2023-02-28 15:15:17+00:00  1630587450710958081
# 2       2023-02-28 15:15:17+00:00  1630587450673319940
# 3       2023-02-28 15:15:17+00:00  1630587450547634179
# 4       2023-02-28 15:15:17+00:00  1630587449503264769
# ...                           ...                  ...
# 105205  2023-02-26 18:13:15+00:00  1629907460935806978
# 105206  2023-02-26 18:04:36+00:00  1629905285090295818
# 105207  2023-02-26 17:50:51+00:00  1629901824546459649
# 105208  2023-02-26 17:35:16+00:00  1629897901660069888
# 105209  2023-02-26 17:28:17+00:00  1629896144561250304
#
#                                                   content  likes  retweets  \
# 0       @BuckTheBoss_ Bitch LMFAOOOOO gone rock the so...      0         0
# 1       @davenewworld_2 Im a nvr VW person simply bc t...      0         0
# 2       I hate wen a bitch say “stop acting like u don...      0         0
# 3       @JJohnson2460 @Todd66251244 @JoJoFromJerz DNC ...      0         0
# 4       Sinong bitch ba yung hindi marunong mag sorry ...      0         0
# ...                                                   ...    ...       ...
# 105205     @SinaiNot @ClownWorld_ https://t.co/1lOP2MS7Px      0         0
# 105206               @ClownWorld_ https://t.co/OeUBZxCOFX      0         0
# 105207  @print3_d @thevivafrei @PierrePoilievre @print...      0         0
# 105208  @FringedCanuck @PierrePoilievre Even the fucki...      3         0
# 105209  @thevivafrei @PierrePoilievre Viva , no he has...      2         0
#
#              disc_cat
# 0              gender
# 1              gender
# 2              gender
# 3              gender
# 4              gender
# ...               ...
# 105205  mental_health
# 105206  mental_health
# 105207  mental_health
# 105208  mental_health
# 105209  mental_health
#
# [105210 rows x 6 columns]

# %%
# Download stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kurtu\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Define regular expressions for hashtags and mentions
hashtag_pattern = re.compile(r'#\w+')
mention_pattern = re.compile(r'@\w+')
url_pattern = re.compile(r'https?://\S+')

# %%
# Define a function to clean the text content of a tweet
def clean_tweets(tweets):
    # Remove hashtags and mentions
    tweets = hashtag_pattern.sub('', tweets)
    tweets = mention_pattern.sub('', tweets)
    tweets = url_pattern.sub('', tweets)
    return tweets

# Apply the clean_tweet function to the 'content' column of the DataFrame
tweets['content'] = tweets['content'].apply(clean_tweets)

# %%
tweets = ['content'].dropna()
# Out:
#                              date                   id  \
# 0       2023-02-28 15:15:17+00:00  1630587451436683264
# 1       2023-02-28 15:15:17+00:00  1630587450710958081
# 2       2023-02-28 15:15:17+00:00  1630587450673319940
# 3       2023-02-28 15:15:17+00:00  1630587450547634179
# 4       2023-02-28 15:15:17+00:00  1630587449503264769
# ...                           ...                  ...
# 105205  2023-02-26 18:13:15+00:00  1629907460935806978
# 105206  2023-02-26 18:04:36+00:00  1629905285090295818
# 105207  2023-02-26 17:50:51+00:00  1629901824546459649
# 105208  2023-02-26 17:35:16+00:00  1629897901660069888
# 105209  2023-02-26 17:28:17+00:00  1629896144561250304
#
#                                                   content  likes  retweets  \
# 0         Bitch LMFAOOOOO gone rock the socks off yo ass😭      0         0
# 1        Im a nvr VW person simply bc the cost of repa...      0         0
# 2       I hate wen a bitch say “stop acting like u don...      0         0
# 3          DNC pays me well.  Ask Brooklyn Dad about i...      0         0
# 4       Sinong bitch ba yung hindi marunong mag sorry ...      0         0
# ...                                                   ...    ...       ...
# 105205                                                         0         0
# 105206                                                         0         0
# 105207      but Canadians will say PPC has no seats or...      0         0
# 105208    Even the fucking Green party supports involv...      3         0
# 105209    Viva , no he hasn't, he's being told what to...      2         0
#
#              disc_cat
# 0              gender
# 1              gender
# 2              gender
# 3              gender
# 4              gender
# ...               ...
# 105205  mental_health
# 105206  mental_health
# 105207  mental_health
# 105208  mental_health
# 105209  mental_health
#
# [105210 rows x 6 columns]
