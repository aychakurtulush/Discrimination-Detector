# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
from tqdm.notebook import tqdm

# %%
# Create an empty DataFrame
df = pd.DataFrame()

# %%
n_tweets = 100000

tweets = []
scraper = sntwitter.TwitterSearchScraper('the')
for j, tweet in tqdm(enumerate(scraper.get_items()), total=n_tweets):
    data = [tweet.date, tweet.id, tweet.content, tweet.likeCount, tweet.retweetCount]
    tweets.append(data)
    if j >= n_tweets:
        break

df = pd.DataFrame(tweets, columns=['date', 'id', 'content', 'likes', 'retweets'])
df = df.assign(disc_cat='control')
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]
# C:\Users\kurtu\AppData\Local\Temp\ipykernel_2376\421456411.py:6: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   data = [tweet.date, tweet.id, tweet.content, tweet.likeCount, tweet.retweetCount]

# %%
df
# Out:
#                             date                   id  \
# 0      2023-03-01 09:09:54+00:00  1630857887038816257
# 1      2023-03-01 09:09:54+00:00  1630857886967496704
# 2      2023-03-01 09:09:54+00:00  1630857886950920192
# 3      2023-03-01 09:09:54+00:00  1630857886778765319
# 4      2023-03-01 09:09:54+00:00  1630857886480908289
# ...                          ...                  ...
# 99996  2023-03-01 08:55:12+00:00  1630854187658489856
# 99997  2023-03-01 08:55:12+00:00  1630854187603959808
# 99998  2023-03-01 08:55:12+00:00  1630854187595472896
# 99999  2023-03-01 08:55:12+00:00  1630854187587100672
# 100000 2023-03-01 08:55:12+00:00  1630854187578712064
#
#                                                   content  likes  retweets  \
# 0       @Marshal38712550 I fully agree for the indepen...      0         0
# 1       @Scott_Wiener And we won't stop till all the f...      1         0
# 2       @JhaSanjay 😂 Rahul Gandhi is in the know of wh...      0         0
# 3       @yabaleftonline I was sleeping o... They came ...      0         0
# 4       Props to the brothers. 👏🏼👏🏼 Excellent work dea...      0         0
# ...                                                   ...    ...       ...
# 99996   🏴󠁧󠁢󠁷󠁬󠁳󠁿A very Happy St David's Day from everyo...      0         0
# 99997   @ARISEtv Congrats sir pls sir what I want for ...      0         0
# 99998             @the_head_ofA ne abbiamo sempre bisogno      0         0
# 99999   @JaqubAjmal Wait, what!\n\nVideo on the channe...      0         0
# 100000  Nhẫn Cartier 3 vòng: Chiêm ngưỡng vẻ đẹp "khôn...      0         0
#
#        disc_cat
# 0       control
# 1       control
# 2       control
# 3       control
# 4       control
# ...         ...
# 99996   control
# 99997   control
# 99998   control
# 99999   control
# 100000  control
#
# [100001 rows x 6 columns]

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#                             date                   id  \
# 0      2023-03-01 09:09:54+00:00  1630857887038816257
# 1      2023-03-01 09:09:54+00:00  1630857886967496704
# 2      2023-03-01 09:09:54+00:00  1630857886950920192
# 3      2023-03-01 09:09:54+00:00  1630857886778765319
# 4      2023-03-01 09:09:54+00:00  1630857886480908289
# ...                          ...                  ...
# 99996  2023-03-01 08:55:12+00:00  1630854187658489856
# 99997  2023-03-01 08:55:12+00:00  1630854187603959808
# 99998  2023-03-01 08:55:12+00:00  1630854187595472896
# 99999  2023-03-01 08:55:12+00:00  1630854187587100672
# 100000 2023-03-01 08:55:12+00:00  1630854187578712064
#
#                                                   content  likes  retweets  \
# 0       @Marshal38712550 I fully agree for the indepen...      0         0
# 1       @Scott_Wiener And we won't stop till all the f...      1         0
# 2       @JhaSanjay 😂 Rahul Gandhi is in the know of wh...      0         0
# 3       @yabaleftonline I was sleeping o... They came ...      0         0
# 4       Props to the brothers. 👏🏼👏🏼 Excellent work dea...      0         0
# ...                                                   ...    ...       ...
# 99996   🏴󠁧󠁢󠁷󠁬󠁳󠁿A very Happy St David's Day from everyo...      0         0
# 99997   @ARISEtv Congrats sir pls sir what I want for ...      0         0
# 99998             @the_head_ofA ne abbiamo sempre bisogno      0         0
# 99999   @JaqubAjmal Wait, what!\n\nVideo on the channe...      0         0
# 100000  Nhẫn Cartier 3 vòng: Chiêm ngưỡng vẻ đẹp "khôn...      0         0
#
#        disc_cat
# 0       control
# 1       control
# 2       control
# 3       control
# 4       control
# ...         ...
# 99996   control
# 99997   control
# 99998   control
# 99999   control
# 100000  control
#
# [100001 rows x 6 columns]

# %%
df.to_csv('Data/tweet_control.csv')
